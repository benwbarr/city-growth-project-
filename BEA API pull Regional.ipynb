# %%
import pandas as pd 
from sqlalchemy import create_engine
import requests
import json
from pprint import pprint
import pybea
from collections import defaultdict
USER_ID = '97B28512-5F7F-4E59-894E-35F0A16A8A47'

# %%
#pybea.get_data_set_list(USER_ID, ResultFormat='JSON')
#raise KeyError('Dataset')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5278db2b0041> in <module>
# ----> 1 pybea.get_data_set_list(USER_ID, ResultFormat='JSON')
#       2 raise KeyError('Dataset')
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\pybea.py in get_data_set_list(UserID, ResultFormat)
#      30     """
#      31     tmp_request = api.DataSetListRequest(UserID=UserID, ResultFormat=ResultFormat)
# ---> 32     return tmp_request.data_set_list
#      33
#      34
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\api.py in data_set_list(self)
#     171     def data_set_list(self):
#     172         if self['ResultFormat'] == 'JSON':
# --> 173             df = pd.DataFrame(self._json_data_set)
#     174         else:
#     175             df = self._elements_to_dataframe(self._xml_data_set, self._dtypes.keys())
#
# ...

# %%
#pybea.get_parameter_list(USER_ID, 'RegionalIncome', ResultFormat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2bb2363688d8> in <module>
# ----> 1 pybea.get_parameter_list(USER_ID, 'RegionalIncome', ResultFormat = "JSON")
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\pybea.py in get_parameter_list(UserID, DataSetName, ResultFormat)
#      78                                            DataSetName=DataSetName,
#      79                                            ResultFormat=ResultFormat)
# ---> 80     return tmp_request.parameter_list
#      81
#      82
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\api.py in parameter_list(self)
#     220     def parameter_list(self):
#     221         if self['ResultFormat'] == 'JSON':
# --> 222             df = pd.DataFrame(self._json_parameter_list)
#     223         else:
#     224             df = self._elements_to_dataframe(self._xml_parameter_list, self._dtypes.keys())
#
# ...

# %%
#data = defaultdict(pybea.get_data(USER_ID,
                      DataSetName='RegionalIncome',
                      TableName='CA1',
                      LineCode=1,
                      GeoFips='COUNTY',
                      Year=['2012', '2013'],
                      ResultFormat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-2e7213c9c43f> in <module>
# ----> 1 data = defaultdict(pybea.get_data(USER_ID,
#       2                       DataSetName='RegionalIncome',
#       3                       TableName='CA1',
#       4                       LineCode=1,
#       5                       GeoFips='COUNTY',
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\pybea.py in get_data(UserID, DataSetName, ResultFormat, **params)
#     199     if DataSetName in valid_dataset_names:
#     200         tmp_request = api.DataRequest(UserID, DataSetName, ResultFormat, **params)
# --> 201         df = tmp_request.data
#     202     else:
#     203         raise ValueError("Invalid DataSetName requested.")
#
# ~\anaconda\Anaconda3\lib\site-packages\pybea\api.py in data(self)
#     367     def data(self):
# ...

# %%
base_url = "https://apps.bea.gov/api/data?UserID=97B28512-5F7F-4E59-894E-35F0A16A8A47&method=GETDATASETLIST&"
return_format = "ResultFormat=JSON"
data1 = requests.get(base_url).json()
pprint(data1)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#                                           'ParameterValue': '97B28512-5F7F-4E59-894E-35F0A16A8A47'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATASETLIST'}]},
#             'Results': {'Dataset': [{'DatasetDescription': 'Standard NIPA '
#                                                            'tables',
#                                      'DatasetName': 'NIPA'},
#                                     {'DatasetDescription': 'Standard NI '
#                                                            'underlying detail '
#                                                            'tables',
#                                      'DatasetName': 'NIUnderlyingDetail'},
#                                     {'DatasetDescription': 'Multinational '
#                                                            'Enterprises',
# ...

# %%
base_url2= "https://apps.bea.gov/api/data?&UserID=97B28512-5F7F-4E59-894E-35F0A16A8A47y&method=getparameterlist&datasetname=Regional&ResultFormat=JSON" 
data3 = requests.get(base_url2).json()
pprint(data3)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETPARAMETERLIST'},
#                                          {'ParameterName': 'USERID',
#                                           'ParameterValue': '97B28512-5F7F-4E59-894E-35F0A16A8A47Y'},
#                                          {'ParameterName': 'DATASETNAME',
#                                           'ParameterValue': 'REGIONAL'}]},
#             'Results': {'Parameter': [{'MultipleAcceptedFlag': '1',
#                                        'ParameterDataType': 'string',
#                                        'ParameterDescription': 'Comma-delimited '
#                                                                'list of '
# ...

# %%
url = "https://apps.bea.gov/api/data?UserID=97B28512-5F7F-4E59-894E-35F0A16A8A47&method=GetData&datasetname=Regional&TableName=CAINC1&LineCode=1&GeoFIPS=STATE&Year=2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020&ResultFormat=JSON"
data2 = requests.get(url).json()
pprint(data2)
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#                                           'ParameterValue': '97B28512-5F7F-4E59-894E-35F0A16A8A47'},
#                                          {'ParameterName': 'LINECODE',
#                                           'ParameterValue': '1'},
#                                          {'ParameterName': 'RESULTFORMAT',
#                                           'ParameterValue': 'JSON'},
#                                          {'ParameterName': 'TABLENAME',
#                                           'ParameterValue': 'CAINC1'},
#                                          {'ParameterName': 'GEOFIPS',
#                                           'ParameterValue': 'STATE'},
#                                          {'ParameterName': 'METHOD',
#                                           'ParameterValue': 'GETDATA'},
#                                          {'ParameterName': 'YEAR',
# ...
